# %%
2 + 5 # левый операнд и правый операнд - это бинарные операторы
10 - 56
6 * 7 # операция умножения
3 + 5 * 4 # =23 - сначала умножение, потом сложение
(3 + 5) * 4 # =32

40 / 8 # деление с остатком
40 // 8 # =5 - операция целочастного деления(без остатка)
40 % 8 # =2 - операция целочисленного деления(получаем только остаток от деления)

2 ** 8 # - операция возведения в степень
2014 ** 14 # 2014 в степени 14
print (pow(2014, 14)) # еще вариант возведения в степень

# унарные операторы:
- 42 
+ 42 # - оператор оставления знака у числа

# Вещественные числа(с плавающей точкой):
0.5
0.5 + 0.3
5 / 2
1 / 3 # 0.3333333333333333 
5e-1 # это значит, что число 5 умножается на 10 в степени -1
1234e2 

    # ТИПЫ ДАННЫХ:

## Числовые:
# целые числа - int
# вещественные - float (с плавуюший точкой)
# логические - bool (False или True)

# Строковые: str
# тип объекта неизменяемый ()
int() # - преобразование в целое число
float()
''' В Пайтоне переменная является указателем на объект. Тип объекта не хранится в переменной, 
он хранится в памяти вместе с самим объектом. 
Таким образом и получается, что мы не можем изменить сам объект напрямую, например, 
прибавить символ цифры или буквы к строке, но мы можем сказать переменной "Эй, переменная, 
показывай мне теперь не на эту строку, а на такую же строку, в конце которой стоит еще вот + этот символ". 
Или " Покажи мне теперь не строку, а цифру". То есть поменяем объект, на который указывает переменная. Например:
s = "Hello" #переменная указывает на строку хэлло
s = s + ", boy!" # создадим новый объект-строку  "Hello" + "boy!" и прикажем переменной указывать на него
в результате print ( s ) вернет "Hello, boy!" '''
type() # - чтобы узнать тип объекта

    # ПЕРЕМЕННЫЕ:

a = 2 # ("=" это оператор присваивания)
b = 5
print (a + b)
a = 6 # - присваиваем новое значение'''
a += 3 # - увеличиваем значением переменной на 3 с помощью оператора приращения
a -= 3
a *= 3
a /= 3
a //= 3
a %= 3
a **= 3

'''Имя переменной:
- может состоять из букв, цифр, подчеркивания 
- должно начинаться с букв или подчеркивания
- не должно быть ключевым словом
- регистр имеет значение '''
# Динамическая типизация - когда переменная меняет тип данных в процессе выполнения программы
# Ввод данных:
input()
a = input() # - записать в переменную пользовательский ввод
a = int(input()) # - прочитать строку с клавиатуры и преобразовать в число
print # - вывод данных, можно вывести несколько переменных через запятую

    # ЛОГИЧЕСКИЕ ЗНАЧЕНИЯ:

False (0)
True (1)
'''
в порядке приоритета:
not - это знак минуса (-) или просто запомнить, что not меняет значение на противоположное
and - это умножение (*)
or - это сложение (+)
'''
# Операции сравнения: <>, <=, >=, == (равно), != (не равно)

    # УСЛОВИЯ:

if a % 2 == 0:
    print ('четное')
    # сюда можно написать еще команды с таким же отступом
elif a % 2 == 1:
    print ('то ли четное то ли нет')
    # если первое условие не верно, то будет выполнятся второе условие
else:
    print ('нечетное') # - будет выполнятся, если ни одно из условии не выполнится
# могут быть конструкции без else или без elif

    # СТРОКИ:

'abc' + 'def' # = abcdef
'abc' * 3 # = abcabcabc
len # функция которая возвращает количество символов в строке
len('abcdef')
# - строки сравниваются в лексикографическом порядке
'abc' == 'def' # true
'abc' < 'ac' 
'abc' < 'ab' 
'\n' - # - символ перевода строки
sep= # для добавления новой строки

f- # для форматирования и выравнивания строки (print(f"Добрый день, {name}."))
# Например, если требуется добавить символы "0" слева (для выравнивания по правому краю), 
# справа (для выравнивания по левому краю) или слева и справа (для выравнивания посередине) 
# от исходной строки до достижения длины в 9 символов: 
print(f"{123:0>9}")
print(f"{123:0<9}")
print(f"{123:0^9}")

print(ord("A")) # - функция для того чтобы узнать уникальное значение какого-нибудь символа
# Out:
# 18064773765607550801425251468864907833685590016

# %%
# Out:
# 500.0
